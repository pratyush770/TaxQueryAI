# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
pune = pd.read_csv('D:/TaxQueryAI/datasets/transformed_data/Property-Tax-Pune.csv')
pune.head()
# Out:
#   City_Name  Zone_Name      Ward_Name  Ward_No  \
# 0      Pune          1          Aundh        8
# 1      Pune          1          Baner       17
# 2      Pune          3   Bhavani Peth        2
# 3      Pune          4     Bibwe Wadi       13
# 4      Pune          2  Chandan Nagar       21
#
#    Tax_Collection_Cr_2013_14_Residential  \
# 0                                  40.60
# 1                                   7.39
# 2                                   6.03
# 3                                  29.22
# 4                                   5.26
#
#    Tax_Collection_Cr_2014_15_Residential  \
# 0                                  42.39
# 1                                   9.25
# 2                                   6.59
# 3                                  28.85
# 4                                   4.90
#
#    Tax_Collection_Cr_2015_16_Residential  \
# 0                                  57.78
# 1                                  14.37
# 2                                  10.24
# 3                                  46.92
# 4                                   7.52
#
#    Tax_Collection_Cr_2016_17_Residential  \
# 0                                  55.35
# 1                                  17.70
# 2                                   7.48
# 3                                  40.81
# 4                                   5.77
#
#    Tax_Collection_Cr_2017_18_Residential  Tax_Demand_Cr_2013_14_Residential  \
# 0                                  55.67                              42.07
# 1                                  17.79                               7.40
# 2                                   6.71                               6.02
# 3                                  42.66                              29.56
# 4                                   5.65                               4.26
#
#    ...  Tax_Collection_Cr_2013_14_Commercial  \
# 0  ...                                 19.88
# 1  ...                                  5.15
# 2  ...                                  6.43
# 3  ...                                 11.63
# 4  ...                                  2.81
#
#    Tax_Collection_Cr_2014_15_Commercial  Tax_Collection_Cr_2015_16_Commercial  \
# 0                                 25.55                                 34.57
# 1                                 10.34                                 11.21
# 2                                  8.59                                  8.94
# 3                                 13.17                                 22.69
# 4                                  2.51                                  3.08
#
#    Tax_Collection_Cr_2016_17_Commercial  Tax_Collection_Cr_2017_18_Commercial  \
# 0                                 44.96                                 32.20
# 1                                 17.16                                 18.79
# 2                                 15.48                                  9.08
# 3                                 28.66                                 19.50
# 4                                  2.69                                  4.68
#
#    Tax_Demand_Cr_2013_14_Commercial  Tax_Demand_Cr_2014_15_Commercial  \
# 0                             27.84                             35.26
# 1                              6.23                             10.36
# 2                              6.97                             16.49
# 3                             13.29                             16.10
# 4                              2.27                              2.35
#
#    Tax_Demand_Cr_2015_16_Commercial  Tax_Demand_Cr_2016_17_Commercial  \
# 0                             38.42                             46.72
# 1                             10.30                             23.36
# 2                              8.80                             17.27
# 3                             27.23                             29.80
# 4                              2.64                              2.70
#
#    Tax_Demand_Cr_2017_18_Commercial
# 0                             42.55
# 1                             21.39
# 2                             11.23
# 3                             26.21
# 4                              3.16
#
# [5 rows x 24 columns]

# %%
tax_sums = pune[[
    'Tax_Demand_Cr_2013_14_Residential',
    'Tax_Demand_Cr_2014_15_Residential',
    'Tax_Demand_Cr_2015_16_Residential',
    'Tax_Demand_Cr_2016_17_Residential',
    'Tax_Demand_Cr_2017_18_Residential'
]].sum(axis=0)

# %%
pune_sum = tax_sums.reset_index()
pune_sum.columns = ['Year', 'Tax Collected (Cr)']
pune_sum
# Out:
#                                 Year  Tax Collected (Cr)
# 0  Tax_Demand_Cr_2013_14_Residential              373.58
# 1  Tax_Demand_Cr_2014_15_Residential              382.03
# 2  Tax_Demand_Cr_2015_16_Residential              445.15
# 3  Tax_Demand_Cr_2016_17_Residential              516.10
# 4  Tax_Demand_Cr_2017_18_Residential              546.97

# %%
X = np.array([2014, 2015, 2016, 2017, 2018]).reshape(-1, 1)
y = pune_sum['Tax Collected (Cr)'].values

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)
y_pred
# Out:
# array([356.596, 404.681, 452.766, 500.851, 548.936])

# %%
plt.plot(y_pred, color="red")
plt.show()

# %%
predicted_tax_2019 = model.predict([[2019]])

# %%
model.score(X, y)
# Out:
# 0.9547467622976644

# %%
print(f"Predicted tax demand for residential in 2019: {predicted_tax_2019[0]} Cr")
# Out:
# Predicted tax demand for residential in 2019: 597.0210000000079 Cr
